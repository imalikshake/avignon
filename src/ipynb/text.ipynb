# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
def show_image(image):
    plt.figure(figsize = (10,20))
    plt.imshow(image)
    plt.axis('off')
    return plt.show()

# %%
def load_image(image_path):
    return cv2.cvtColor(cv2.imread(image_path), cv2.COLOR_BGR2RGB)

# %%
def save_image(image_path, image):
    return cv2.imwrite(image_path, cv2.cvtColor(image, cv2.COLOR_RGB2BGR))

# %%
def fuzzy_edges(image, min_g=1, max_g=4):
    kernel_size = (25, 25)  # Adjust the kernel size for the desired blur effect
    blurred_image = cv2.GaussianBlur(image, kernel_size, 0)
    # Create a mask for the edges using Canny edge detection
    edges = cv2.Canny(image, min_g, max_g)  # Adjust the threshold values for desired edge detection
    # edge_mask = cv2.cvtColor(edges, cv2.COLOR_GRAY2BGR)
    # Combine the blurred image with the original image using the edge mask
    # fuzzy_edges_image = np.where(edge_mask != 0, blurred_image, image)
    return edges

# %%
image_path="/Users/iman/github/avi/test3/video_o/testimony1078.jpg"
# image_path="/Users/iman/Downloads/-methode-times-prod-web-bin-3b40019e-655b-11eb-ab68-123bacbc1c7b.jpg"

# Read the image
image = load_image(image_path)
image = f_image
# Define the text parameters
text = '80% 80%'
font = cv2.FONT_HERSHEY_SIMPLEX
font_scale = 5.0
color = (255, 255, 255)  # White color
thickness = 20

# Add the text to the image
text_size, _ = cv2.getTextSize(text, font, font_scale, thickness)

text_x = int((image.shape[1] - text_size[0]) / 2)
text_y = int((image.shape[0] + text_size[1]) / 2)

# Add the text to the image
_ = cv2.putText(image, text, (text_x, text_y), font, font_scale, color, thickness)
_ = cv2.putText(image, text, (text_x, text_y-200), font, font_scale, color, thickness)
_ = cv2.putText(image, text, (text_x, text_y-400), font, font_scale, color, thickness)
_ = cv2.putText(image, text, (text_x, text_y-600), font, font_scale, color, thickness)
_ = cv2.putText(image, text, (text_x, text_y-800), font, font_scale, color, thickness)
_ = cv2.putText(image, text, (text_x, text_y-1000), font, font_scale, color, thickness)
_ = cv2.putText(image, text, (text_x, text_y+1200), font, font_scale, color, thickness)
_ = cv2.putText(image, text, (text_x, text_y+200), font, font_scale, color, thickness)
_ = cv2.putText(image, text, (text_x, text_y+400), font, font_scale, color, thickness)
_ = cv2.putText(image, text, (text_x, text_y+600), font, font_scale, color, thickness)
_ = cv2.putText(image, text, (text_x, text_y+800), font, font_scale, color, thickness)
_ = cv2.putText(image, text, (text_x, text_y+1000), font, font_scale, color, thickness)
_ = cv2.putText(image, text, (text_x, text_y+1200), font, font_scale, color, thickness)

# %%
f_image = fuzzy_edges(image)

# %%
show_image(image)

# %%
# Alternatively, you can save the image to disk:
save_image("/Users/iman/github/avi/test3/test.jpg", image)
save_image("/Users/iman/github/avi/test3/test2.jpg", f_image)
# Out:
# True
